# %%
import numpy as np
import pandas as pd
import json
from collections import Counter

# %%
invalid_counts = {}

# %%
KEY1 = "A1"
KEY2 = "A2"

# %% [markdown]
# ## Data Paths

# %%
user_data_path = "data/study/user_data.csv"
data_paths = {
    "response_data" : {
        KEY1 : "data/study/response_data_{}.csv".format(KEY1),
        KEY2 : "data/study/response_data_{}.csv".format(KEY2)
    },
    "demographics" : {
        KEY1 : "data/study/demographics_data_{}.csv".format(KEY1),
        KEY2 : "data/study/demographics_data_{}.csv".format(KEY2)
    }
}

# %% [markdown]
# # Join Dataframes for subsets

# %%
datasets = [KEY1, KEY2]
response_data_header = ["User ID", "Question Number", "Question", "Breed Key", "Image Name", "User Response", "Correct Response", "Response Time"]
response_data_dfs_raw = []
for dataset_id in datasets:
    df_raw = pd.read_csv(data_paths["response_data"][dataset_id], header=None)
    
    # Set header
    df_raw.columns = response_data_header
    
    # Join A1
    df_processed = df_raw.join(pd.DataFrame({'Dataset': [dataset_id for _ in range(len(df_raw))]}))
    
    if response_data_dfs_raw != []:
        previous_length = len(response_data_dfs_raw[-1])
        current_length = len(df_processed)
        new_upper_bound = previous_length + current_length
        df_processed.index = [i for i in range(previous_length, new_upper_bound)]        
    
    # Store
    response_data_dfs_raw.append(df_processed)

response_data_dfs = pd.concat(response_data_dfs_raw, axis=0)
response_data_dfs
# Out:
#       User ID  Question Number                                       Question  \
# 0          21                0  Is this image Dog Breed A or not Dog Breed A?
# 1          21                1  Is this image Dog Breed A or not Dog Breed A?
# 2          21                2  Is this image Dog Breed A or not Dog Breed A?
# 3          21                3  Is this image Dog Breed A or not Dog Breed A?
# 4          21                4  Is this image Dog Breed A or not Dog Breed A?
# 5          21                5  Is this image Dog Breed A or not Dog Breed A?
# 6          21                6  Is this image Dog Breed A or not Dog Breed A?
# 7          21                7  Is this image Dog Breed A or not Dog Breed A?
# 8          21                8  Is this image Dog Breed A or not Dog Breed A?
# 9          21                9  Is this image Dog Breed A or not Dog Breed A?
# 10         21               10  Is this image Dog Breed A or not Dog Breed A?
# 11         21               11  Is this image Dog Breed A or not Dog Breed A?
# 12         21               12  Is this image Dog Breed A or not Dog Breed A?
# 13         21               13  Is this image Dog Breed A or not Dog Breed A?
# 14         21               14  Is this image Dog Breed A or not Dog Breed A?
# 15         21               15  Is this image Dog Breed A or not Dog Breed A?
# 16         21               16  Is this image Dog Breed A or not Dog Breed A?
# 17         21               17  Is this image Dog Breed A or not Dog Breed A?
# 18         21               18  Is this image Dog Breed A or not Dog Breed A?
# 19         21               19  Is this image Dog Breed A or not Dog Breed A?
# 20         21               20  Is this image Dog Breed A or not Dog Breed A?
# 21         21               21  Is this image Dog Breed A or not Dog Breed A?
# 22         21               22  Is this image Dog Breed A or not Dog Breed A?
# 23         21               23  Is this image Dog Breed A or not Dog Breed A?
# 24         21               24  Is this image Dog Breed A or not Dog Breed A?
# 25         21               25  Is this image Dog Breed A or not Dog Breed A?
# 26         21               26  Is this image Dog Breed A or not Dog Breed A?
# 27         21               27  Is this image Dog Breed A or not Dog Breed A?
# 28         21               28  Is this image Dog Breed A or not Dog Breed A?
# 29         21               29  Is this image Dog Breed A or not Dog Breed A?
# ...       ...              ...                                            ...
# 4650       66               74  Is this image Dog Breed A or not Dog Breed A?
# 4651       66               75  Is this image Dog Breed A or not Dog Breed A?
# 4652       66               76  Is this image Dog Breed A or not Dog Breed A?
# 4653       66               77  Is this image Dog Breed A or not Dog Breed A?
# 4654       66               78  Is this image Dog Breed A or not Dog Breed A?
# 4655       66               79  Is this image Dog Breed A or not Dog Breed A?
# 4656       66               80  Is this image Dog Breed A or not Dog Breed A?
# 4657       66               81  Is this image Dog Breed A or not Dog Breed A?
# 4658       66               82  Is this image Dog Breed A or not Dog Breed A?
# 4659       66               83  Is this image Dog Breed A or not Dog Breed A?
# 4660       66               84  Is this image Dog Breed A or not Dog Breed A?
# 4661       66               85  Is this image Dog Breed A or not Dog Breed A?
# 4662       66               86  Is this image Dog Breed A or not Dog Breed A?
# 4663       66               87  Is this image Dog Breed A or not Dog Breed A?
# 4664       66               88  Is this image Dog Breed A or not Dog Breed A?
# 4665       66               89  Is this image Dog Breed A or not Dog Breed A?
# 4666       66               90  Is this image Dog Breed A or not Dog Breed A?
# 4667       66               91  Is this image Dog Breed A or not Dog Breed A?
# 4668       66               92  Is this image Dog Breed A or not Dog Breed A?
# 4669       66               93  Is this image Dog Breed A or not Dog Breed A?
# 4670       66               94  Is this image Dog Breed A or not Dog Breed A?
# 4671       66               95  Is this image Dog Breed A or not Dog Breed A?
# 4672       66               96  Is this image Dog Breed A or not Dog Breed A?
# 4673       66               97  Is this image Dog Breed A or not Dog Breed A?
# 4674       66               98  Is this image Dog Breed A or not Dog Breed A?
# 4675       66               99  Is this image Dog Breed A or not Dog Breed A?
# 4676       66              100  Is this image Dog Breed A or not Dog Breed A?
# 4677       66              101  Is this image Dog Breed A or not Dog Breed A?
# 4678       66              102  Is this image Dog Breed A or not Dog Breed A?
# 4679       66              103  Is this image Dog Breed A or not Dog Breed A?
#
#                                               Breed Key  \
# 0     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 1     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 2     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 3     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 4     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 5     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 6     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 7     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 8     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 9     dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 10    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 11    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 12    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 13    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 14    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 15    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 16    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 17    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 18    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 19    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 20    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 21    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 22    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 23    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 24    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 25    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 26    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 27    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 28    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 29    dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# ...                                                 ...
# 4650  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4651  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4652  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4653  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4654  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4655  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4656  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4657  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4658  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4659  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4660  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4661  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4662  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4663  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4664  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4665  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4666  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4667  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4668  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4669  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4670  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4671  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4672  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4673  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4674  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4675  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4676  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4677  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4678  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
# 4679  dog_A : saint_bernard\r\ndog_B : basset_hound\r\n
#
#                                              Image Name User Response  \
# 0            static/imgs/study/dogs/dog_B__142__dr2.png             B
# 1           static/imgs/study/dogs/dog_B__166__dr10.png             B
# 2            static/imgs/study/dogs/dog_A__152__dr2.png             A
# 3             static/imgs/study/dogs/dog_B__24__dr5.png             B
# 4             static/imgs/study/dogs/dog_B__96__dr7.png             B
# 5            static/imgs/study/dogs/dog_B__91__dr10.png             B
# 6             static/imgs/study/dogs/dog_A__76__dr7.png             A
# 7            static/imgs/study/dogs/dog_A__103__dr2.png             A
# 8             static/imgs/study/dogs/dog_B__26__dr2.png             B
# 9            static/imgs/study/dogs/dog_A__164__dr2.png             A
# 10           static/imgs/study/dogs/dog_A__169__dr5.png             A
# 11          static/imgs/study/dogs/dog_B__180__dr10.png             B
# 12           static/imgs/study/dogs/dog_A__103__dr7.png             B
# 13          static/imgs/study/dogs/dog_B__142__dr10.png             B
# 14           static/imgs/study/dogs/dog_A__164__dr7.png             A
# 15           static/imgs/study/dogs/dog_B__180__dr5.png             B
# 16           static/imgs/study/dogs/dog_B__142__dr5.png             B
# 17            static/imgs/study/dogs/dog_B__96__dr2.png             B
# 18            static/imgs/study/dogs/dog_B__24__dr2.png             B
# 19           static/imgs/study/dogs/dog_B__124__dr7.png             B
# 20    static/imgs/study/attention_check/dog_A__150__...             A
# 21           static/imgs/study/dogs/dog_B__171__dr7.png             B
# 22           static/imgs/study/dogs/dog_A__137__dr7.png             A
# 23           static/imgs/study/dogs/dog_A__149__dr2.png             A
# 24            static/imgs/study/dogs/dog_A__39__dr5.png             A
# 25            static/imgs/study/dogs/dog_B__91__dr2.png             A
# 26            static/imgs/study/dogs/dog_B__99__dr7.png             B
# 27           static/imgs/study/dogs/dog_A__90__dr10.png             B
# 28           static/imgs/study/dogs/dog_A__114__dr2.png             A
# 29           static/imgs/study/dogs/dog_A__152__dr5.png             B
# ...                                                 ...           ...
# 4650        static/imgs/study/dogs/dog_B__142__dr10.png             A
# 4651          static/imgs/study/dogs/dog_A__40__dr5.png             A
# 4652          static/imgs/study/dogs/dog_A__50__dr7.png             A
# 4653          static/imgs/study/dogs/dog_B__41__dr2.png             B
# 4654          static/imgs/study/dogs/dog_B__53__dr5.png             B
# 4655         static/imgs/study/dogs/dog_B__142__dr2.png             B
# 4656         static/imgs/study/dogs/dog_B__190__dr7.png             A
# 4657          static/imgs/study/dogs/dog_B__6__dr10.png             A
# 4658           static/imgs/study/dogs/dog_B__1__dr7.png             B
# 4659  static/imgs/study/attention_check/dog_A__91__c...             B
# 4660         static/imgs/study/dogs/dog_B__123__dr7.png             B
# 4661         static/imgs/study/dogs/dog_A__50__dr10.png             A
# 4662          static/imgs/study/dogs/dog_A__10__dr2.png             A
# 4663          static/imgs/study/dogs/dog_B__41__dr5.png             B
# 4664           static/imgs/study/dogs/dog_A__8__dr7.png             A
# 4665          static/imgs/study/dogs/dog_A__40__dr2.png             A
# 4666         static/imgs/study/dogs/dog_B__198__dr2.png             A
# 4667        static/imgs/study/dogs/dog_A__112__dr10.png             A
# 4668          static/imgs/study/dogs/dog_A__53__dr7.png             A
# 4669          static/imgs/study/dogs/dog_A__32__dr2.png             A
# 4670         static/imgs/study/dogs/dog_A__129__dr7.png             A
# 4671          static/imgs/study/dogs/dog_A__32__dr5.png             A
# 4672          static/imgs/study/dogs/dog_A__44__dr7.png             A
# 4673          static/imgs/study/dogs/dog_A__44__dr2.png             A
# 4674         static/imgs/study/dogs/dog_B__119__dr7.png             A
# 4675          static/imgs/study/dogs/dog_B__1__dr10.png             A
# 4676         static/imgs/study/dogs/dog_B__119__dr5.png             B
# 4677          static/imgs/study/dogs/dog_B__19__dr5.png             B
# 4678         static/imgs/study/dogs/dog_B__145__dr2.png             B
# 4679         static/imgs/study/dogs/dog_A__116__dr5.png             A
#
#       Correct Response  Response Time Dataset
# 0                 True           6639      A1
# 1                 True           3171      A1
# 2                 True           1259      A1
# 3                 True           1122      A1
# 4                 True           1320      A1
# 5                 True           1014      A1
# 6                 True           1018      A1
# 7                 True           1049      A1
# 8                 True            906      A1
# 9                 True           1144      A1
# 10                True            897      A1
# 11                True           1160      A1
# 12               False           1008      A1
# 13                True           1026      A1
# 14                True            982      A1
# 15                True            875      A1
# 16                True           1530      A1
# 17                True           1462      A1
# 18                True            841      A1
# 19                True            800      A1
# 20                True           1185      A1
# 21                True           2406      A1
# 22                True           1554      A1
# 23                True           1317      A1
# 24                True           1012      A1
# 25               False           1248      A1
# 26                True            887      A1
# 27               False            874      A1
# 28                True            934      A1
# 29               False            913      A1
# ...                ...            ...     ...
# 4650             False           1134      A2
# 4651              True           4139      A2
# 4652              True           2137      A2
# 4653              True           3108      A2
# 4654              True           1731      A2
# 4655              True           1582      A2
# 4656             False           2078      A2
# 4657             False           4038      A2
# 4658              True           2822      A2
# 4659             False           3283      A2
# 4660              True            997      A2
# 4661              True           1068      A2
# 4662              True           1430      A2
# 4663              True           2541      A2
# 4664              True           1445      A2
# 4665              True           1442      A2
# 4666             False           3774      A2
# 4667              True           1272      A2
# 4668              True           1201      A2
# 4669              True           1338      A2
# 4670              True           1305      A2
# 4671              True           2204      A2
# 4672              True           1403      A2
# 4673              True           1546      A2
# 4674             False           1963      A2
# 4675             False            880      A2
# 4676              True           1202      A2
# 4677              True            841      A2
# 4678              True            867      A2
# 4679              True           4210      A2
#
# [4680 rows x 9 columns]

# %% [markdown]
# # Update Image Name

# %%
new_image_names = []
for index, row in response_data_dfs.iterrows():
    row_breed_key = row["Breed Key"]
    row_image_name = row["Image Name"]
    row_breed_key = row_breed_key.strip().split("\n")
    row_breed_dict = { ele.split(":")[0].strip() : ele.split(":")[1].strip() for ele in row_breed_key}

    if "dog_A" in row_image_name:
        new_image_name = row_image_name.replace("dog_A", row_breed_dict["dog_A"])
    else:
        new_image_name = row_image_name.replace("dog_B", row_breed_dict["dog_B"])
    
    new_image_names.append(new_image_name)

# %%
response_data_dfs["Image Name"] = new_image_names

# %%
response_data_dfs.head()
# Out:
#    User ID  Question Number                                       Question  \
# 0       21                0  Is this image Dog Breed A or not Dog Breed A?
# 1       21                1  Is this image Dog Breed A or not Dog Breed A?
# 2       21                2  Is this image Dog Breed A or not Dog Breed A?
# 3       21                3  Is this image Dog Breed A or not Dog Breed A?
# 4       21                4  Is this image Dog Breed A or not Dog Breed A?
#
#                                            Breed Key  \
# 0  dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 1  dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 2  dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 3  dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
# 4  dog_A : basset_hound\r\ndog_B : saint_bernard\r\n
#
#                                           Image Name User Response  \
# 0  static/imgs/study/dogs/saint_bernard__142__dr2...             B
# 1  static/imgs/study/dogs/saint_bernard__166__dr1...             B
# 2  static/imgs/study/dogs/basset_hound__152__dr2.png             A
# 3  static/imgs/study/dogs/saint_bernard__24__dr5.png             B
# 4  static/imgs/study/dogs/saint_bernard__96__dr7.png             B
#
#    Correct Response  Response Time Dataset
# 0              True           6639      A1
# 1              True           3171      A1
# 2              True           1259      A1
# 3              True           1122      A1
# 4              True           1320      A1

# %% [markdown]
# ## Check image counts

# %%
counts = Counter(response_data_dfs["Image Name"])
average_count_per_image = np.mean(counts.values())
print("Average count per image: {}".format(average_count_per_image))
# Out:
# Average count per image: 22.5

# %% [markdown]
# ## Remove Bad Users

# %%
user_IDs = set(response_data_dfs["User ID"])

invalid_users = {}
valid_user_ids = []
for user_id in user_IDs:
    
    user_is_valid = True
    fail_reasons = []
    user_df = response_data_dfs[response_data_dfs["User ID"] == user_id]
    
    # CHECK NUMBER OF USER ENTRIES! Ensure 103
    # ========================================================
    num_user_entries = len(user_df)
    
    if num_user_entries < 103:
        fail_reason = "User {} does not have 103 entries - they have {}.".format(user_id, num_user_entries)
        fail_reasons.append(fail_reason)
        user_is_valid = False
        
    elif num_user_entries == 206:
        fail_reason = "User {} has 206 entries! Readjusting dataframe.".format(user_id)
        
        unique_sets = set(user_df["Dataset"])
        if unique_sets == 2:
            keep_set = datasets[np.random.randint(2)]
            user_df = user_df[user_df["Dataset"] == keep_set]
        else:
            user_df = user_df[:103]
    # ========================================================
    
    # CHECK THAT USERS DID NOT ENTER ONLY 1 ANSWER: e.g., all B's
    # ========================================================
    user_responses = user_df["User Response"]
    unique_responses = set(user_responses)
    
    if len(unique_responses) == 1:
        fail_reason = "User {} only entered {}'s".format(user_id, list(unique_responses)[0])
        fail_reasons.append(fail_reason)
        user_is_valid = False
    # ========================================================
    
    # CHECK THAT USERS PASSED ATTENTION CHECKS
    # ========================================================
    attention_check_threshold = 2
    attention_check_correct_responses = user_df[user_df["Image Name"].str.contains('attention_check')]["Correct Response"]
    attention_checks_passed = len(np.where(attention_check_correct_responses == True)[0])
    if attention_checks_passed < attention_check_threshold:
        fail_reason = "User {} only passed {}/4 attention checks!".format(user_id, attention_checks_passed)
        fail_reasons.append(fail_reason)
        user_is_valid = False
    # ========================================================
    
    if not user_is_valid:
        invalid_users[user_id] = {"reasons" : fail_reasons}
    else:
        valid_user_ids.append(user_id)
   
invalid_user_ids = invalid_users.keys()

num_total_users = len(user_IDs)
print("Total users: {}".format(num_total_users))

print("\n")

print("Invalid Users")
print("-------------")
for user_i, (invalid_user_id, val) in enumerate(invalid_users.items(), 1):
    print("\t{}. User {} -- Reasons: {}".format(user_i, invalid_user_id, val["reasons"][0]))

print("\n")

print("Valid Users")
print("-----------")
for valid_i, valid_user_id in enumerate(valid_user_ids):
    print("\t{:2.0f}. User {}".format(valid_i, valid_user_id))
# Out:
# Total users: 31
#
#
# Invalid Users
# -------------
# 	1. User 66 -- Reasons: User 66 only passed 0/4 attention checks!
# 	2. User 3 -- Reasons: User 3 only passed 0/4 attention checks!
# 	3. User 37 -- Reasons: User 37 only passed 0/4 attention checks!
# 	4. User 7 -- Reasons: User 7 only passed 0/4 attention checks!
# 	5. User 8 -- Reasons: User 8 only passed 0/4 attention checks!
# 	6. User 9 -- Reasons: User 9 only passed 1/4 attention checks!
# 	7. User 48 -- Reasons: User 48 only passed 0/4 attention checks!
# 	8. User 17 -- Reasons: User 17 only passed 0/4 attention checks!
# 	9. User 52 -- Reasons: User 52 only passed 0/4 attention checks!
# 	10. User 53 -- Reasons: User 53 only passed 0/4 attention checks!
# 	11. User 57 -- Reasons: User 57 only passed 0/4 attention checks!
#
#
# Valid Users
# -----------
# 	 0. User 18
# 	 1. User 21
# 	 2. User 22
# 	 3. User 23
# 	 4. User 26
# 	 5. User 30
# 	 6. User 32
# 	 7. User 34
# 	 8. User 40
# 	 9. User 43
# 	10. User 44
# 	11. User 49
# 	12. User 50
# 	13. User 55
# 	14. User 56
# 	15. User 60
# 	16. User 64
# 	17. User 65
# 	18. User 67
# 	19. User 196

# %%
set_ = "Set{}".format(KEY1[0])
invalid_counts[set_] = 20 - len(valid_user_ids)

# %%
invalid_counts
# Out:
# {'SetA': 0}

# %% [markdown]
# ## Get correctness of images

# %%
# Unique Image list
unique_image_list = set(response_data_dfs["Image Name"])

# Remove attention checks
downsampled_image_list = [image for image in unique_image_list if "attention_check" not in image]

full_data = {}
for dog_image in downsampled_image_list:

    full_data[dog_image] = {}
    
    # Get dog DF
    dog_df = response_data_dfs[response_data_dfs["Image Name"] == dog_image]
    
    # Users associated with current image
    user_df = list(dog_df["User ID"])
    
    # Get valid indices for df
    valid_indices = []
    for user_i, user_id in enumerate(user_df):
        if user_id in valid_user_ids:
            valid_indices.append(user_i)
            
    # Get observations for current image only from valid users
    valid_images_df = dog_df.iloc[valid_indices]

    # Count number of images in df
    valid_image_count = len(valid_images_df["Correct Response"])
       
    # Setup breed key and inverted breed key
    # ==========================================================================================
    breed_key = list(valid_images_df["Breed Key"])[0]
    breed_key = [breed.strip() for breed in breed_key.split("\n") if breed.strip() != ""]
    breed_key = {breed.split(" : ")[0] : breed.split(" : ")[1] for breed in breed_key}
    breed_key_inv = { val : key for key, val in breed_key.items()}
    # ==========================================================================================
    
    # Get correctness
    correct_count = len(valid_images_df[valid_images_df["Correct Response"] == True])
    correctness = correct_count / float(valid_image_count)
    full_data[dog_image]["correctness"] = correctness
    
    # Get confidence
    # First, find majority vote and label
    label_counts = Counter(valid_images_df["User Response"])
    
    user_response_1 = valid_images_df["User Response"].iloc[0]
    correct_response_1 = valid_images_df["Correct Response"].iloc[0]
    
    if not correct_response_1:
        user_response_1 = "B" if user_response_1 == "A" else "A"
    actual_label = "dog_{}".format(user_response_1)
    actual_label = breed_key[actual_label]
    
    majority_label = "dog_A" if label_counts["A"] > label_counts["B"] else "dog_B"
    majority_label = breed_key[majority_label]
    
    
    confidence = label_counts["A"] / float(valid_image_count) if label_counts["A"] > label_counts["B"] else label_counts["B"] / float(valid_image_count)
    
    # update data struct
    full_data[dog_image]["confidence"] = {
        "actual_label" : actual_label, 
        "majority_label" : majority_label, 
        "value" : confidence
    }

# %%
data = full_data

# %%
data
# Out:
# {'static/imgs/study/dogs/basset_hound__103__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5217391304347826},
#   'correctness': 0.5217391304347826},
#  'static/imgs/study/dogs/basset_hound__103__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__103__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__103__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6086956521739131},
#   'correctness': 0.6086956521739131},
#  'static/imgs/study/dogs/basset_hound__111__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.5652173913043478},
#   'correctness': 0.43478260869565216},
#  'static/imgs/study/dogs/basset_hound__111__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__111__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__111__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6521739130434783},
#   'correctness': 0.6521739130434783},
#  'static/imgs/study/dogs/basset_hound__114__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6521739130434783},
#   'correctness': 0.6521739130434783},
#  'static/imgs/study/dogs/basset_hound__114__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__114__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__114__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/basset_hound__119__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__119__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__119__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__119__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__120__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__120__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__120__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__120__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__123__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__123__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__123__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__123__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__137__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.21739130434782608},
#  'static/imgs/study/dogs/basset_hound__137__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__137__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__137__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5217391304347826},
#   'correctness': 0.5217391304347826},
#  'static/imgs/study/dogs/basset_hound__142__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__142__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__142__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__142__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__144__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.6521739130434783},
#   'correctness': 0.34782608695652173},
#  'static/imgs/study/dogs/basset_hound__144__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__144__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__144__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6956521739130435},
#   'correctness': 0.6956521739130435},
#  'static/imgs/study/dogs/basset_hound__145__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__145__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__145__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__145__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__149__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__149__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__149__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__149__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__152__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.6956521739130435},
#   'correctness': 0.30434782608695654},
#  'static/imgs/study/dogs/basset_hound__152__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__152__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/basset_hound__152__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.6086956521739131},
#   'correctness': 0.391304347826087},
#  'static/imgs/study/dogs/basset_hound__164__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__164__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__164__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/basset_hound__164__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__169__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/basset_hound__169__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__169__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__169__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__190__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__190__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__190__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__190__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.42857142857142855},
#  'static/imgs/study/dogs/basset_hound__198__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__198__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__198__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__198__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__19__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__19__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__19__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__19__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__1__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__1__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__1__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__1__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__39__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6956521739130435},
#   'correctness': 0.6956521739130435},
#  'static/imgs/study/dogs/basset_hound__39__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/basset_hound__39__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__39__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/basset_hound__41__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.42857142857142855},
#  'static/imgs/study/dogs/basset_hound__41__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__41__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__41__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__53__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/basset_hound__53__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__53__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__53__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__6__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__6__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/basset_hound__6__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__6__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__76__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.5217391304347826},
#   'correctness': 0.4782608695652174},
#  'static/imgs/study/dogs/basset_hound__76__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/basset_hound__76__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/basset_hound__76__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6956521739130435},
#   'correctness': 0.6956521739130435},
#  'static/imgs/study/dogs/basset_hound__78__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/basset_hound__78__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__78__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__78__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/basset_hound__90__dr10.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'saint_bernard',
#    'value': 0.5652173913043478},
#   'correctness': 0.43478260869565216},
#  'static/imgs/study/dogs/basset_hound__90__dr2.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__90__dr5.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/basset_hound__90__dr7.png': {'confidence': {'actual_label': 'basset_hound',
#    'majority_label': 'basset_hound',
#    'value': 0.6956521739130435},
#   'correctness': 0.6956521739130435},
#  'static/imgs/study/dogs/saint_bernard__10__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__10__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__10__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__10__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__112__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__112__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__112__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__112__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__116__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__116__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__116__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__116__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__124__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5652173913043478},
#   'correctness': 0.5652173913043478},
#  'static/imgs/study/dogs/saint_bernard__124__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__124__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/saint_bernard__124__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/saint_bernard__126__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__126__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__126__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__126__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/saint_bernard__129__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.8571428571428571},
#   'correctness': 0.14285714285714285},
#  'static/imgs/study/dogs/saint_bernard__129__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__129__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/saint_bernard__129__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.2857142857142857},
#  'static/imgs/study/dogs/saint_bernard__142__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.6086956521739131},
#   'correctness': 0.6086956521739131},
#  'static/imgs/study/dogs/saint_bernard__142__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__142__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__142__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__166__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/saint_bernard__166__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__166__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__166__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__171__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/saint_bernard__171__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__171__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__171__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/saint_bernard__180__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__180__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__180__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__180__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__18__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/saint_bernard__18__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__18__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__18__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__24__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__24__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9565217391304348},
#   'correctness': 0.9565217391304348},
#  'static/imgs/study/dogs/saint_bernard__24__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__24__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__26__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__26__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__26__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__26__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7391304347826086},
#   'correctness': 0.7391304347826086},
#  'static/imgs/study/dogs/saint_bernard__32__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__32__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__32__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__32__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__40__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__40__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__40__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__40__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__44__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__44__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__44__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__44__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/saint_bernard__50__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__50__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__50__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__50__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__53__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__53__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__53__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__53__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__75__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.42857142857142855},
#  'static/imgs/study/dogs/saint_bernard__75__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8571428571428571},
#   'correctness': 0.8571428571428571},
#  'static/imgs/study/dogs/saint_bernard__75__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.42857142857142855},
#  'static/imgs/study/dogs/saint_bernard__75__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__79__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__79__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__79__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__79__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__8__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.7142857142857143},
#   'correctness': 0.2857142857142857},
#  'static/imgs/study/dogs/saint_bernard__8__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__8__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__8__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/saint_bernard__91__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__91__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/saint_bernard__91__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__91__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/saint_bernard__94__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.5714285714285714},
#   'correctness': 0.5714285714285714},
#  'static/imgs/study/dogs/saint_bernard__94__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 1.0},
#   'correctness': 1.0},
#  'static/imgs/study/dogs/saint_bernard__94__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.7142857142857143},
#   'correctness': 0.7142857142857143},
#  'static/imgs/study/dogs/saint_bernard__94__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'basset_hound',
#    'value': 0.5714285714285714},
#   'correctness': 0.42857142857142855},
#  'static/imgs/study/dogs/saint_bernard__96__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.6956521739130435},
#   'correctness': 0.6956521739130435},
#  'static/imgs/study/dogs/saint_bernard__96__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/saint_bernard__96__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8695652173913043},
#   'correctness': 0.8695652173913043},
#  'static/imgs/study/dogs/saint_bernard__96__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174},
#  'static/imgs/study/dogs/saint_bernard__99__dr10.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__99__dr2.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.9130434782608695},
#   'correctness': 0.9130434782608695},
#  'static/imgs/study/dogs/saint_bernard__99__dr5.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.8260869565217391},
#   'correctness': 0.8260869565217391},
#  'static/imgs/study/dogs/saint_bernard__99__dr7.png': {'confidence': {'actual_label': 'saint_bernard',
#    'majority_label': 'saint_bernard',
#    'value': 0.782608695652174},
#   'correctness': 0.782608695652174}}

# %% [markdown]
# # Policy Generation

# %% [markdown]
# # Policies
#  1. Random (basically interspersed)
#  2. All low confidence (correctness interspersed)
#  3. All high confidence (correctness interspersed)
#  4. Low to high confidence
#  5. High to low confidence
#
# ### High / Low Confidence Determined Empirically
#     - Take the median

# %%
get_median_confidence = lambda x : np.mean([i["confidence"]["value"] for i in x.values()])

# %%
confidence_threshold = get_median_confidence(data)
confidence_threshold
# Out:
# 0.8096894409937887

# %%
policy_data = {}

# %% [markdown]
# ### Policy 1: Random

# %%
policy_1_raw = data.items()
np.random.shuffle(policy_1_raw)
policy_1 = []
for key, val in policy_1_raw:
    new_data = (key, {
        "confidence" : val["confidence"]["value"], 
        "correctness" : val["correctness"],
        "majority_label" : val["confidence"]["majority_label"]})
    policy_1.append(new_data)
print("Shuffled List")
policy_1[:5]
# Out:
# Shuffled List
# [('static/imgs/study/dogs/saint_bernard__18__dr7.png',
#   {'confidence': 1.0, 'correctness': 1.0, 'majority_label': 'saint_bernard'}),
#  ('static/imgs/study/dogs/basset_hound__149__dr2.png',
#   {'confidence': 0.8695652173913043,
#    'correctness': 0.8695652173913043,
#    'majority_label': 'basset_hound'}),
#  ('static/imgs/study/dogs/basset_hound__53__dr5.png',
#   {'confidence': 0.8571428571428571,
#    'correctness': 0.8571428571428571,
#    'majority_label': 'basset_hound'}),
#  ('static/imgs/study/dogs/saint_bernard__171__dr5.png',
#   {'confidence': 0.9130434782608695,
#    'correctness': 0.9130434782608695,
#    'majority_label': 'saint_bernard'}),
#  ('static/imgs/study/dogs/basset_hound__39__dr7.png',
#   {'confidence': 0.782608695652174,
#    'correctness': 0.782608695652174,
#    'majority_label': 'basset_hound'})]

# %%
policy_data["policy_1"] = policy_1

# %% [markdown]
# ### Policy 2: All low confidence (correctness interspersed)

# %%
policy_2 = []
num_query_images = 0
for key, val in data.items():
    if val["confidence"]["value"] < confidence_threshold:
        query_this_point = True
        num_query_images += 1
    else:
        query_this_point = False
        
    new_data = (key, {
        "confidence" : val["confidence"]["value"], 
        "correctness" : val["correctness"],
        "majority_label" : val["confidence"]["majority_label"],
        "query" : query_this_point})
    policy_2.append(new_data)

np.random.shuffle(policy_2)
policy_2[:4]

print(num_query_images)
# Out:
# 83

# %%
policy_data["policy_2"] = policy_2

# %% [markdown]
# ### Policy 3: All high confidence (correctness interspersed)

# %%
policy_3 = []
for key, val in data.items():
    if val["confidence"]["value"] >= confidence_threshold:
        query_this_point = True
    else:
        query_this_point = False
        
    new_data = (key, {
        "confidence" : val["confidence"]["value"], 
        "correctness" : val["correctness"],
        "majority_label" : val["confidence"]["majority_label"],
        "query" : query_this_point})
    policy_3.append(new_data)

np.random.shuffle(policy_3)
policy_3[:4]
# Out:
# [('static/imgs/study/dogs/basset_hound__123__dr7.png',
#   {'confidence': 0.7142857142857143,
#    'correctness': 0.7142857142857143,
#    'majority_label': 'basset_hound',
#    'query': False}),
#  ('static/imgs/study/dogs/basset_hound__149__dr10.png',
#   {'confidence': 0.7391304347826086,
#    'correctness': 0.7391304347826086,
#    'majority_label': 'basset_hound',
#    'query': False}),
#  ('static/imgs/study/dogs/basset_hound__103__dr2.png',
#   {'confidence': 0.9130434782608695,
#    'correctness': 0.9130434782608695,
#    'majority_label': 'basset_hound',
#    'query': True}),
#  ('static/imgs/study/dogs/basset_hound__152__dr5.png',
#   {'confidence': 0.782608695652174,
#    'correctness': 0.782608695652174,
#    'majority_label': 'basset_hound',
#    'query': False})]

# %%
policy_data["policy_3"] = policy_3

# %% [markdown]
# ### Policy 4: Low to high confidence

# %%
key_dict = data.keys()
dtype=[('a', float), ('b', float), ('c', 'U25'), ('d', int)]

policy_4 = np.array([(val["confidence"]["value"], val["correctness"], val["confidence"]["majority_label"], key_dict.index(key)) for key, val in data.items()], dtype=dtype)
policy_4 = np.sort(policy_4, order=['a'])
policy_4 = [(key_dict[i[3]], {"confidence" : i[0], "correctness" : i[1], "majority_label" : str(i[2])}) for i in policy_4]
for i, ele in enumerate(policy_4):
    if i > 4: break
    print(ele)
# Out:
# ('static/imgs/study/dogs/basset_hound__76__dr10.png', {'majority_label': 'saint_bernard', 'confidence': 0.5217391304347826, 'correctness': 0.4782608695652174})
# ('static/imgs/study/dogs/basset_hound__103__dr10.png', {'majority_label': 'basset_hound', 'confidence': 0.5217391304347826, 'correctness': 0.5217391304347826})
# ('static/imgs/study/dogs/basset_hound__137__dr7.png', {'majority_label': 'basset_hound', 'confidence': 0.5217391304347826, 'correctness': 0.5217391304347826})
# ('static/imgs/study/dogs/basset_hound__90__dr10.png', {'majority_label': 'saint_bernard', 'confidence': 0.5652173913043478, 'correctness': 0.43478260869565216})
# ('static/imgs/study/dogs/basset_hound__111__dr10.png', {'majority_label': 'saint_bernard', 'confidence': 0.5652173913043478, 'correctness': 0.43478260869565216})

# %%
policy_data["policy_4"] = policy_4

# %% [markdown]
# ### Policy 5: High to low confidence

# %%
policy_5 = policy_4[::-1]
for i, ele in enumerate(policy_5):
    if i > 4: break
    print(ele)
# Out:
# ('static/imgs/study/dogs/saint_bernard__116__dr2.png', {'majority_label': 'saint_bernard', 'confidence': 1.0, 'correctness': 1.0})
# ('static/imgs/study/dogs/saint_bernard__50__dr10.png', {'majority_label': 'saint_bernard', 'confidence': 1.0, 'correctness': 1.0})
# ('static/imgs/study/dogs/saint_bernard__53__dr2.png', {'majority_label': 'saint_bernard', 'confidence': 1.0, 'correctness': 1.0})
# ('static/imgs/study/dogs/saint_bernard__18__dr7.png', {'majority_label': 'saint_bernard', 'confidence': 1.0, 'correctness': 1.0})
# ('static/imgs/study/dogs/saint_bernard__129__dr2.png', {'majority_label': 'saint_bernard', 'confidence': 1.0, 'correctness': 1.0})

# %%
policy_data["policy_5"] = policy_5

# %% [markdown]
# ### Write Data

# %%
study_out = "Set{}".format(KEY1[0])
study_out
# Out:
# 'SetA'

# %%
with open("../2_experiment_primary/studies/{}/static/data/study_1_full_data.json".format(study_out), "w") as outfile:
    json.dump(data, outfile)

# %%
with open("../2_experiment_primary/studies/{}/static/data/study_1_results.json".format(study_out), "w") as outfile:
    json.dump(policy_data, outfile)
